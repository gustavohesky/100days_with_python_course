# %%
'''Scope and global variables'''

enemies = 1

def increase_enemies():
    enemies = 2
    print(f"enemies inside the functions: {enemies}")

increase_enemies()

print(f"enemies outside the function: {enemies}")



# Local Scope 

def drink_potion():
    potion_strengh = 2
    print(potion_strengh)

drink_potion()
# print(potion_strength) #error because potion strength is not defined outside the function

# Global Scope

player_health = 10 #this is a global variable

def game():

    def drink_potion():
        potion_strengh = 2
        print(player_health)

  

drink_potion()
print(player_health)
# Out:
# enemies inside the functions: 2
# enemies outside the function: 1
# 2
# 2
# 10

# %%
player_health = 10 #this is a global variable

def game():

    def drink_potion():
        potion_strengh = 2
        print(player_health)

  

# drink_potion() this will be an error as we cannot access the function as it's local
print(player_health)
# Out:
# 10

# %%
game_level = 3
enemies = ['Skeleton','Zombie','Alien']

def create_enemy():
    new_enemy = ""
    if game_level < 5:
        new_enemy = enemies[0]
    print(new_enemy)

# %%
def is_prime(num):
    if num ==2:
        return True
    if num ==1:
        return False
    
    for i in range(2,num):
        if num % i ==0:
            return False
    
    return True

is_prime(16)
# Out:
# False

# %%
enemies = 1

def increase_enemies(enemy):
    print(f"enemies inside the functions: {enemies}")
    return enemy + 1

enemies = increase_enemies(enemies)

print(f"enemies outside the function: {enemies}")
# Out:
# enemies inside the functions: 1
# enemies outside the function: 2
