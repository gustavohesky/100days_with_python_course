# %%
'''Debug'''

def my_function():
    for i in range(1,20):
        if i ==20:
            print("You got it")

my_function()

# Describing the problem

# In this case the problem is that the condition in the if statement is never true because the loop iterates from 1 to 19, and never reaches 20.
# Fixing the problem

def my_function():
    for i in range(1, 21):
        if i == 20:
            print("You got it")

my_function()
# Out:
# You got it

# %%
from random import randint

dice_imgs = ["1️⃣", "2️⃣", "3️⃣", "4️⃣", "5️⃣", "6️⃣"]
dice_num = randint(0,5)
print(dice_imgs[dice_num])
# Out:
# 1️⃣

# %%
year = int(input("What's your year of birth?"))
if year > 1980 and year < 1994:
    print("You are a millenial.")
elif year >1994:
    print("You are a Gen Z.")

# The issue here is that if someone was born in 1994, they would not be classified as either a millennial or Gen Z. To fix this, we can change the condition to include the year 1994 in the millennial category.


year = int(input("What's your year of birth?"))
if year > 1980 and year < 1994:
    print("You are a millenial.")
elif year >= 1994:
    print("You are a Gen Z.")

# %%
try:
    age = int(input("How old are you?"))
    if age > 18:
        print("You can drive at age {age}.")
except ValueError:
    print("Please enter a valid number for age.")

# The issue here is that the variable 'age' is not being used in the print statement. To fix this, we can use an f-string to include the value of 'age' in the output.

try:
    age = int(input("How old are you?"))
    if age > 18:
        print(f"You can drive at age {age}.")
except ValueError:
    print("Please enter a valid number for age.")
# Out:
# You can drive at age 30.

# %%
word_per_page = 0
pages =int(input("Number of pages: "))
word_per_page =int(input("Number of words per page: "))
total_words = pages * word_per_page
print(total_words)

# the issue here is that the variable 'word_per_page' is being compared to the input value instead of being assigned the input value. To fix this, we need to change the '==' operator to '='.
# Out:
# 778500
