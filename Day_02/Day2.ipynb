# %%
'''Subscripting'''
print("Hello"[0]) #Adding the index to print a specific letter. It always starts with 0
print("Hello"[-2]) # using negative, it starts the count from the end
# Out:
# H
# l

# %%
#String
print("123" + "456") # it will not sum the numbers but it will concatenate them as it's a string

#Integer = Whole number
print(123+456) # It will sum the numbers

#Large numbers

print(123_456_789)

#Float

print(3.14159)

#Boolean
print(True)
print(False)
# Out:
# 123456
# 579
# 123456789
# 3.14159
# True
# False

# %%
type("Hello") # use type to identify the data type
print(type("Hello"))
print(type(123))
print(type(123.456))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
'''Type Conversion'''

int("123") # converts the string to integer
float(10) # converts the int to float
str(10) # converts the int to string

print("Number of letters in your name: "+str(len(input("Enter your name: "))))

# The formula above only works because len is being converted to string, otherwise an error message will be displayed
# Out:
# Number of letters in your name: 7

# %%
'''Mathematical Operations'''

print("My age: "+str(30))
print(123+456) # Sum
print(7-3) # Sub
print(3*2) # Multi
print(5/2)  # Div
print(5//3) # Floor Div
print(2**3) # Exponencial

# PEMDASLR

# ()
# **
# * OR /
# + OR -

print(3 * 3 + 3 / 3 - 3)
# Out:
# My age: 30
# 579
# 4
# 6
# 2.5
# 1
# 8
# 7.0

# %%
'''BMI Calculator'''

height = 1.65
weight = 84

bmi = weight/(height**2)

print((bmi))
# Out:
# 30.85399449035813

# %%
print(round(bmi,2)) # using round
# Out:
# 30.85

# %%
score = 0

#user scores a point
score += 1
print(score)
# Out:
# 1

# %%
# f-strings

age = 12
print(f"I am {age} years old")

score = 0
height = 1.8
is_winning = True

print(f"Your Score is = {score}, your height is {height}. You are winning is {is_winning}")
# Out:
# I am 12 years old
# Your Score is = 0, your height is 1.8. You are winning is True

# %%
'''Tip Calculator'''

print("Welcome to the tip calculator!")
bill = float(input("What was the total bill? €"))
tip = int(input("How much tip you would like to give? 10, 12 or 15? "))
num_people = int(input("How many people to split the bill? "))
final_bill = float(round((bill * (1 + tip/100))/num_people,2))
print(f"Each person needs to pay €{final_bill}")
# Out:
# Welcome to the tip calculator!
# Each person needs to pay €33.0
